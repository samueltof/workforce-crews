# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Breakdown of Website Project Requirements
#
# #### Project Overview:
# The goal is to create a responsive, modern website for a small business that effectively engages users, showcases services, and facilitates communication. The project will be executed in Phases, ensuring that all aspects are covered thoroughly before launching.
#
# ### Task Breakdown
#
# 1. **Create Responsive Design**
#    - **Scope:** Design a layout that automatically adjusts to various screen sizes (desktop, tablet, mobile).
#    - **Timeline:** 2 weeks (From Nov 1, 2023, to Nov 14, 2023)
#    - **Dependencies:** None
#    - **Deliverables:** Wireframes for all pages in desktop and mobile formats.
#    - **Responsible:** Bob Smith (Designer)
#
# 2. **Implement User Interface**
#    - **Scope:** Build a visually appealing interface following the defined style guide with a modern feel.
#    - **Timeline:** 3 weeks (From Nov 15, 2023, to Dec 5, 2023)
#    - **Dependencies:** Completion of responsive design.
#    - **Deliverables:** Fully developed front-end interface for review.
#    - **Responsible:** Jane Doe (Software Engineer), Bob Smith (Designer)
#
# 3. **Develop Navigation System**
#    - **Scope:** Create a menu structure that is easy to navigate and enhances user experience.
#    - **Timeline:** 1 week (From Dec 6, 2023, to Dec 12, 2023)
#    - **Dependencies:** Completion of UI Implementation.
#    - **Deliverables:** Interactive prototype of the navigation for testing.
#    - **Responsible:** Jane Doe (Software Engineer)
#
# 4. **Create "About Us" Page**
#    - **Scope:** Write content highlighting the company’s history, mission, and values.
#    - **Timeline:** 1 week (From Dec 13, 2023, to Dec 19, 2023)
#    - **Dependencies:** None
#    - **Deliverables:** Completed "About Us" page.
#    - **Responsible:** Alice Johnson (QA Engineer), with support from John Doe (Project Manager)
#
# 5. **Design "Services" Page**
#    - **Scope:** Showcase the services offered by the business, with detailed descriptions.
#    - **Timeline:** 1 week (From Dec 20, 2023, to Dec 26, 2023)
#    - **Dependencies:** Completion of "About Us" page.
#    - **Deliverables:** Completed "Services" page.
#    - **Responsible:** Bob Smith (Designer)
#
# 6. **Create "Contact Us" Page**
#    - **Scope:** Develop a contact form with required fields and integrate a map for location.
#    - **Timeline:** 1 week (From Dec 27, 2023, to Jan 2, 2024)
#    - **Dependencies:** Completion of the “Services” page.
#    - **Deliverables:** Completed "Contact Us" page.
#    - **Responsible:** Jane Doe (Software Engineer)
#
# 7. **Implement Blog Section**
#    - **Scope:** Create a blog section for publishing news and updates, allowing for easy content management.
#    - **Timeline:** 2 weeks (From Jan 3, 2024, to Jan 16, 2024)
#    - **Dependencies:** Completion of previous pages.
#    - **Deliverables:** Functional blog section with at least 2 initial posts.
#    - **Responsible:** Jane Doe (Software Engineer)
#
# 8. **Optimize for Fast Loading (SEO)**
#    - **Scope:** Ensure that all elements are optimized for speed and incorporated search engine optimization best practices.
#    - **Timeline:** 1 week (From Jan 17, 2024, to Jan 23, 2024)
#    - **Dependencies:** Completion of website construction (all pages).
#    - **Deliverables:** SEO optimization report.
#    - **Responsible:** Jane Doe (Software Engineer)
#
# 9. **Integrate Social Media Links**
#    - **Scope:** Add social media icons and sharing capabilities to the website.
#    - **Timeline:** 1 week (From Jan 24, 2024, to Jan 30, 2024)
#    - **Dependencies:** Completion of the website.
#    - **Deliverables:** Integrated social media features.
#    - **Responsible:** Jane Doe (Software Engineer)
#
# 10. **Include Testimonials Section**
#     - **Scope:** Create a section where customer feedback is displayed.
#     - **Timeline:** 1 week (From Jan 31, 2024, to Feb 6, 2024)
#     - **Dependencies:** Completion of previous tasks.
#     - **Deliverables:** Completed testimonials section.
#     - **Responsible:** Bob Smith (Designer)
#
# 11. **Quality Assurance Testing**
#     - **Scope:** Perform thorough testing of the entire website to find and fix bugs.
#     - **Timeline:** 2 weeks (From Feb 7, 2024, to Feb 21, 2024)
#     - **Dependencies:** Completion of all pages/features.
#     - **Deliverables:** QA report and list of bugs/issues addressed.
#     - **Responsible:** Alice Johnson & Tom Brown (QA Engineers)
#
# 12. **Launch Website**
#     - **Scope:** Provide go-live support, monitor traffic, and receive immediate feedback.
#     - **Timeline:** 1 week (From Feb 22, 2024, to Feb 28, 2024)
#     - **Dependencies:** Completion of QA Testing.
#     - **Deliverables:** Live website and post-launch summary report.
#     - **Responsible:** John Doe (Project Manager)
#
# ### Timeline Visualization - Gantt Chart
#
# | Task                          | Start Date  | End Date    | Duration |
# |-------------------------------|-------------|-------------|----------|
# | Create Responsive Design      | Nov 1, 2023| Nov 14, 2023| 2 weeks  |
# | Implement User Interface      | Nov 15, 2023| Dec 5, 2023 | 3 weeks  |
# | Develop Navigation System     | Dec 6, 2023 | Dec 12, 2023| 1 week   |
# | Create "About Us" Page       | Dec 13, 2023| Dec 19, 2023| 1 week   |
# | Design "Services" Page       | Dec 20, 2023| Dec 26, 2023| 1 week   |
# | Create "Contact Us" Page     | Dec 27, 2023| Jan 2, 2024 | 1 week   |
# | Implement Blog Section        | Jan 3, 2024 | Jan 16, 2024| 2 weeks  |
# | Optimize for Fast Loading     | Jan 17, 2024| Jan 23, 2024| 1 week   |
# | Integrate Social Media Links  | Jan 24, 2024| Jan 30, 2024| 1 week   |
# | Include Testimonials Section   | Jan 31, 2024| Feb 6, 2024 | 1 week   |
# | Quality Assurance Testing      | Feb 7, 2024 | Feb 21, 2024| 2 weeks  |
# | Launch Website                | Feb 22, 2024| Feb 28, 2024| 1 week   |
#
# ### Dependencies
# - Each part of the website relies on the previous section's completion.
# - Design-related tasks depend on the initial responsive design phase being completed.
#
# This detailed plan ensures all aspects of the Website project are specified, tracked, and completed successfully, ultimately delivering a high-quality site tailored to the business needs, ready for launch.
#
# #### Overall Completion
# - **Project Start Date:** November 1, 2023
# - **Project End Date:** February 28, 2024
#
# This meticulous breakdown covers all elements required for the successful launch of the website.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### 1. Create Responsive Design
# - **Estimated Time:** 2 weeks
# - **Resources Required:**
#   - 1 Designer (Bob Smith)
#   - Design software (Adobe XD, Figma, etc.)
# - **Effort:** Approximately 80 hours (40 hours/week)
# - **Risks/Uncertainties:**
#   - Miscommunication regarding design requirements could lead to rework.
#   - Potential delays in feedback from stakeholders.
#
# #### 2. Implement User Interface
# - **Estimated Time:** 3 weeks
# - **Resources Required:**
#   - 1 Software Engineer (Jane Doe)
#   - 1 Designer (Bob Smith)
#   - Development tools (HTML, CSS, JavaScript frameworks)
# - **Effort:** Approximately 120 hours (40 hours/week split between 2 resources)
# - **Risks/Uncertainties:**
#   - Complexity in aligning UI with responsive design may require additional time.
#   - Unexpected bugs could arise during development.
#
# #### 3. Develop Navigation System
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Software Engineer (Jane Doe)
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Navigation design changes could delay implementation.
#   - User feedback may necessitate further tweaks.
#
# #### 4. Create "About Us" Page
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 QA Engineer (Alice Johnson)
#   - 1 Project Manager (John Doe) for proofreading and guidance.
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Content may require multiple revisions.
#   - Stakeholder input might introduce delays.
#
# #### 5. Design "Services" Page
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Designer (Bob Smith)
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Content layout and structure may change based on user feedback.
#
# #### 6. Create "Contact Us" Page
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Software Engineer (Jane Doe)
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Integrating location mapping can be complex and time-consuming.
#
# #### 7. Implement Blog Section
# - **Estimated Time:** 2 weeks
# - **Resources Required:**
#   - 1 Software Engineer (Jane Doe)
# - **Effort:** Approximately 80 hours
# - **Risks/Uncertainties:**
#   - CMS integration may encounter issues.
#   - Training on content management may be required for the client.
#
# #### 8. Optimize for Fast Loading (SEO)
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Software Engineer (Jane Doe)
#   - SEO tools and plugins.
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - SEO strategies might change, requiring additional optimization.
#   - Performance testing could reveal further necessary adjustments.
#
# #### 9. Integrate Social Media Links
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Software Engineer (Jane Doe)
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Potential issues with API integrations.
#   - Client decisions on which platforms to include can affect timeline.
#
# #### 10. Include Testimonials Section
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Designer (Bob Smith)
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Gathering and approving customer testimonials can delay development.
#
# #### 11. Quality Assurance Testing
# - **Estimated Time:** 2 weeks
# - **Resources Required:**
#   - 2 QA Engineers (Alice Johnson & Tom Brown)
#   - Testing tools (Selenium, BrowserStack, etc.)
# - **Effort:** Approximately 160 hours
# - **Risks/Uncertainties:**
#   - A significant number of bugs could extend testing time.
#   - Late changes in functionality may require retesting.
#
# #### 12. Launch Website
# - **Estimated Time:** 1 week
# - **Resources Required:**
#   - 1 Project Manager (John Doe)
# - **Effort:** Approximately 40 hours
# - **Risks/Uncertainties:**
#   - Technical issues during launch may require a rollback.
#   - User feedback post-launch may require quick adjustments.
#
# ### Summary of Overall Project
# - **Estimated Total Duration:** 12 weeks from November 1, 2023, to February 28, 2024
# - **Total Effort Required:** Approximately 680 hours
# - **Key Dependencies:**
#   - Each task is sequentially dependent, meaning delays in early tasks could impact the entire project timeline.
#
# ### Summary of Risks
# - The main risks include potential miscommunications, complex technical integrations, content revisions, and stakeholder delays. Effective communication, regular check-ins, and a flexible project approach can help mitigate these risks throughout the project lifecycle.
#
# This detailed report outlines the time, resources, effort, and risks associated with each task, ensuring a clear roadmap for the successful execution of the website project.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                | Team Member(s)             | Start Date  | End Date    | Estimated Hours |
# |-------------------------------------|-----------------------------|-------------|-------------|------------------|
# | Create Responsive Design             | Bob Smith                   | Nov 1, 2023 | Nov 14, 2023| 80               |
# | Implement User Interface            | Jane Doe, Bob Smith        | Nov 15, 2023| Dec 5, 2023 | 120              |
# | Develop Navigation System           | Jane Doe                   | Dec 6, 2023 | Dec 12, 2023| 40               |
# | Create "About Us" Page             | Alice Johnson, John Doe    | Dec 13, 2023| Dec 19, 2023| 40               |
# | Design "Services" Page             | Bob Smith                   | Dec 20, 2023| Dec 26, 2023| 40               |
# | Create "Contact Us" Page           | Jane Doe                   | Dec 27, 2023| Jan 2, 2024 | 40               |
# | Implement Blog Section              | Jane Doe                   | Jan 3, 2024 | Jan 16, 2024| 80               |
# | Optimize for Fast Loading (SEO)    | Jane Doe                   | Jan 17, 2024| Jan 23, 2024| 40               |
# | Integrate Social Media Links        | Jane Doe                   | Jan 24, 2024| Jan 30, 2024| 40               |
# | Include Testimonials Section        | Bob Smith                   | Jan 31, 2024| Feb 6, 2024 | 40               |
# | Quality Assurance Testing            | Alice Johnson, Tom Brown    | Feb 7, 2024 | Feb 20, 2024| 160              |
# | Launch Website                      | John Doe                   | Feb 21, 2024| Feb 28, 2024| 40               |
#
# ### Summary and Rationale Behind Each Allocation Decision
#
# 1. **Create Responsive Design (Bob Smith)**: As the sole designer on the team, Bob will focus on creating the responsive design for the website, which is crucial for user experience. The task duration is set for 2 weeks to allow for revisions based on stakeholder feedback.
#
# 2. **Implement User Interface (Jane Doe & Bob Smith)**: This task crucially requires both coding skills and design sensibility. Jane will handle the software engineering part while Bob will provide design insights. The overlap with Bob's previous task ensures coherence in the UI.
#
# 3. **Develop Navigation System (Jane Doe)**: Jane's capabilities as a Software Engineer make her the right choice for this simpler but essential task, with a focused time frame of 1 week.
#
# 4. **Create "About Us" Page (Alice Johnson & John Doe)**: This page will require input from the QA Engineer to test the content. John as Project Manager will oversee it to ensure proper alignment with project goals.
#
# 5. **Design "Services" Page (Bob Smith)**: Continuation from the responsive design project allows Bob to maintain consistency in visual design aspects while managing his time efficiently.
#
# 6. **Create "Contact Us" Page (Jane Doe)**: Jane, with her software skills, will also be responsible for this page, ensuring cohesive integration with the overall website framework.
#
# 7. **Implement Blog Section (Jane Doe)**: Given the complexity involved in a blog’s technical integration, Jane has the software skills to take this on. Her previous knowledge of the entire UI will aid in a timely delivery.
#
# 8. **Optimize for Fast Loading (SEO) (Jane Doe)**: This task follows the implementation of other features, ideally suited for Jane who will ensure integration of the SEO strategies.
#
# 9. **Integrate Social Media Links (Jane Doe)**: As a continuation of her work, Jane will handle this alongside API integrations she is likely already familiar with.
#
# 10. **Include Testimonials Section (Bob Smith)**: Bob will design this section while engaging with content gathering processes. This task is strategically timed to run concurrently with previous design tasks.
#
# 11. **Quality Assurance Testing (Alice Johnson & Tom Brown)**: Both QA Engineers will carry out exhaustive testing in 2 weeks, ensuring all parts of the website adhere to project standards and function correctly.
#
# 12. **Launch Website (John Doe)**: As the Project Manager, John will lead the final launch phase while ensuring all aspects of the project are aligned with the initial requirements before the public release.
#
# This allocation plan strategically leverages individual strengths and manages workload effectively, ensuring the project is well-staffed while promoting collaboration among team members. By balancing the tasks, overall project success and efficiency are maximized.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0031
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         20485          12488               7997                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Develop Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create "About Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson', 'John Doe']},
#   {'task_name': 'Design "Services" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Create "Contact Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize for Fast Loading (SEO)',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 160.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe']}],
#  'milestones': [{'milestone_name': 'Design Phase Completion',
#    'tasks': ['Create Responsive Design',
#     'Implement User Interface',
#     'Develop Navigation System',
#     'Create "About Us" Page',
#     'Design "Services" Page']},
#   {'milestone_name': 'Development Phase Completion',
#    'tasks': ['Create "Contact Us" Page',
#     'Implement Blog Section',
#     'Optimize for Fast Loading (SEO)',
#     'Integrate Social Media Links',
#     'Include Testimonials Section']},
#   {'milestone_name': 'Testing Phase Completion',
#    'tasks': ['Quality Assurance Testing']},
#   {'milestone_name': 'Project Launch', 'tasks': ['Launch Website']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_7629f th {
#   font-size: 120%;
# }
# #T_7629f  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_7629f" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7629f_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_7629f_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_7629f_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7629f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7629f_row0_col0" class="data row0 col0" >Create Responsive Design</td>
#       <td id="T_7629f_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_7629f_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7629f_row1_col0" class="data row1 col0" >Implement User Interface</td>
#       <td id="T_7629f_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_7629f_row1_col2" class="data row1 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7629f_row2_col0" class="data row2 col0" >Develop Navigation System</td>
#       <td id="T_7629f_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_7629f_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7629f_row3_col0" class="data row3 col0" >Create "About Us" Page</td>
#       <td id="T_7629f_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_7629f_row3_col2" class="data row3 col2" >['Alice Johnson', 'John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7629f_row4_col0" class="data row4 col0" >Design "Services" Page</td>
#       <td id="T_7629f_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_7629f_row4_col2" class="data row4 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7629f_row5_col0" class="data row5 col0" >Create "Contact Us" Page</td>
#       <td id="T_7629f_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_7629f_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7629f_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_7629f_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_7629f_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7629f_row7_col0" class="data row7 col0" >Optimize for Fast Loading (SEO)</td>
#       <td id="T_7629f_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_7629f_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7629f_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_7629f_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_7629f_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7629f_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_7629f_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_7629f_row9_col2" class="data row9 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7629f_row10_col0" class="data row10 col0" >Quality Assurance Testing</td>
#       <td id="T_7629f_row10_col1" class="data row10 col1" >160.000000</td>
#       <td id="T_7629f_row10_col2" class="data row10 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_7629f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7629f_row11_col0" class="data row11 col0" >Launch Website</td>
#       <td id="T_7629f_row11_col1" class="data row11 col1" >40.000000</td>
#       <td id="T_7629f_row11_col2" class="data row11 col2" >['John Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_2e533 th {
#   font-size: 120%;
# }
# #T_2e533  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_2e533" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e533_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_2e533_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e533_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e533_row0_col0" class="data row0 col0" >Design Phase Completion</td>
#       <td id="T_2e533_row0_col1" class="data row0 col1" >['Create Responsive Design', 'Implement User Interface', 'Develop Navigation System', 'Create "About Us" Page', 'Design "Services" Page']</td>
#     </tr>
#     <tr>
#       <th id="T_2e533_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e533_row1_col0" class="data row1 col0" >Development Phase Completion</td>
#       <td id="T_2e533_row1_col1" class="data row1 col1" >['Create "Contact Us" Page', 'Implement Blog Section', 'Optimize for Fast Loading (SEO)', 'Integrate Social Media Links', 'Include Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_2e533_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e533_row2_col0" class="data row2 col0" >Testing Phase Completion</td>
#       <td id="T_2e533_row2_col1" class="data row2 col1" >['Quality Assurance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_2e533_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e533_row3_col0" class="data row3 col0" >Project Launch</td>
#       <td id="T_2e533_row3_col1" class="data row3 col1" >['Launch Website']</td>
#     </tr>
#   </tbody>
# </table>
